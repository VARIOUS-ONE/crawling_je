# %%
import pandas as pd
import glob
import os

# %%
a = pd.read_csv('./rev_data/rev_0824_star1_1.csv',encoding = 'cp949', index_col=0)
a
# Out:
#                                                     상품명          날짜  \
# 0     [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2018.11.06
# 1     [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2018.12.09
# 2     [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2020.02.01
# 3     [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2020.10.30
# 4     [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2020.07.07
# ...                                                 ...         ...
# 3333  KF94 KF-AD 여름용 아이코코 마스크 비말차단 / 컬러에디션 초소형 소형 S ...  2021.12.11
# 3334  KF94 KF-AD 여름용 아이코코 마스크 비말차단 / 컬러에디션 초소형 소형 S ...  2022.04.08
# 3335  KF94 KF-AD 여름용 아이코코 마스크 비말차단 / 컬러에디션 초소형 소형 S ...  2022.03.09
# 3336  KF94 KF-AD 여름용 아이코코 마스크 비말차단 / 컬러에디션 초소형 소형 S ...  2022.02.17
# 3337  KF94 KF-AD 여름용 아이코코 마스크 비말차단 / 컬러에디션 초소형 소형 S ...  2021.12.17
#
#                 ID  평점                                                 리뷰   꾹
# ...

# %%
b = pd.read_csv('./rev_data/rev_0824_star1_2.csv',encoding = 'cp949',index_col=0)
b
# Out:
#                                                     상품명          날짜  \
# 0      [소프시스] 접이식 책상 1인용 학생 공부 H형 책상 좌식 커피 서브 소파 폴딩 테이블  2022.08.06
# 1     헤네스 즉할15%+15% 무료발송 시즌오프 모자/아동모자/데일리머리끈/ 당고 헤어끈/ 코  2022.08.24
# 2     헤네스 즉할15%+15% 무료발송 시즌오프 모자/아동모자/데일리머리끈/ 당고 헤어끈/ 코  2022.05.31
# 3     헤네스 즉할15%+15% 무료발송 시즌오프 모자/아동모자/데일리머리끈/ 당고 헤어끈/ 코  2022.07.04
# 4     헤네스 즉할15%+15% 무료발송 시즌오프 모자/아동모자/데일리머리끈/ 당고 헤어끈/ 코  2022.05.17
# ...                                                 ...         ...
# 1556  [프리메라] 한가위 대잔치 특별구성!프리메라X 헬리녹스 리미티드 외 BEST! #수달인형  2022.07.14
# 1557  [프리메라] 한가위 대잔치 특별구성!프리메라X 헬리녹스 리미티드 외 BEST! #수달인형  2022.06.03
# 1558  [프리메라] 한가위 대잔치 특별구성!프리메라X 헬리녹스 리미티드 외 BEST! #수달인형  2021.11.20
# 1559  [프리메라] 한가위 대잔치 특별구성!프리메라X 헬리녹스 리미티드 외 BEST! #수달인형  2022.06.09
# 1560  [프리메라] 한가위 대잔치 특별구성!프리메라X 헬리녹스 리미티드 외 BEST! #수달인형  2019.01.28
#
#                 ID  평점                                                 리뷰  꾹
# ...

# %%
c = pd.read_csv('./rev_data/rev_0824_star1_3.csv',encoding = 'cp949',index_col=0)
c
# Out:
#                                                     상품명          날짜  \
# 0     [20%+T11%+묶음10%] 닥터지 추석 브랜드위크! 피부건강 선물기획 外 BES...  2021.05.02
# 1     [20%+T11%+묶음10%] 닥터지 추석 브랜드위크! 피부건강 선물기획 外 BES...  2021.05.28
# 2     [20%+T11%+묶음10%] 닥터지 추석 브랜드위크! 피부건강 선물기획 外 BES...  2021.04.29
# 3     [20%+T11%+묶음10%] 닥터지 추석 브랜드위크! 피부건강 선물기획 外 BES...  2019.11.22
# 4     [20%+T11%+묶음10%] 닥터지 추석 브랜드위크! 피부건강 선물기획 外 BES...  2019.04.18
# ...                                                 ...         ...
# 1929                              [본사] 더미식 장인라면/즉석밥 모음전  2022.04.07
# 1930                   고려은단 비타민C 1000 600정 X 1개 (20개월분)  2021.07.17
# 1931                   고려은단 비타민C 1000 600정 X 1개 (20개월분)  2021.07.17
# 1932                   고려은단 비타민C 1000 600정 X 1개 (20개월분)  2021.11.12
# 1933                   고려은단 비타민C 1000 600정 X 1개 (20개월분)  2021.09.04
#
#                        ID  평점  \
# 0                bits****   1
# 1               choi*****   1
# 2                   분홍선인장   1
# ...

# %%
d = pd.read_csv('./rev_data/rev_0824_star1_4.csv',encoding = 'utf-8-sig',index_col=0)
d
# Out:
#                                                 상품명          날짜  \
# 0             [아이오페]추석 선물세트는 아이오페와 함께! 피크닉의자 단독 증정!  2019.11.15
# 1             [아이오페]추석 선물세트는 아이오페와 함께! 피크닉의자 단독 증정!  2019.11.19
# 2             [아이오페]추석 선물세트는 아이오페와 함께! 피크닉의자 단독 증정!  2020.04.15
# 3             [아이오페]추석 선물세트는 아이오페와 함께! 피크닉의자 단독 증정!  2021.01.15
# 4             [아이오페]추석 선물세트는 아이오페와 함께! 피크닉의자 단독 증정!  2021.05.07
# ...                                             ...         ...
# 13886  햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트  2022.02.12
# 13887  햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트  2021.10.23
# 13888  햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트  2022.04.01
# 13889  햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트  2020.12.11
# 13890  햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트  2022.04.01
#
#                           ID  평점  \
# 0                     now데렐라   1
# 1                 love******   1
# 2                        강냉콩   1
# 3      dudt*****************   1
# ...

# %%
rev_star1_0824 = pd.concat([a, b, c, d], axis=0)

# %%
rev_star1_0824
# Out:
#                                                      상품명          날짜  \
# 0      [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2018.11.06
# 1      [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2018.12.09
# 2      [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2020.02.01
# 3      [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2020.10.30
# 4      [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2020.07.07
# ...                                                  ...         ...
# 13886       햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트  2022.02.12
# 13887       햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트  2021.10.23
# 13888       햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트  2022.04.01
# 13889       햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트  2020.12.11
# 13890       햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트  2022.04.01
#
#                  ID  평점                                                 리뷰   꾹
# ...

# %%
rev_star1_0824.to_csv("rev_star1_0824.csv", encoding='utf-8-sig')

# %%
a = pd.read_csv('./1점크롤링_완료.csv',encoding = 'utf-8-sig', index_col=0)
a
# Out:
#                                                      상품명          날짜  \
# 0      [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2018.11.06
# 1      [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2018.12.09
# 2      [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2020.02.01
# 3      [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2020.10.30
# 4      [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2020.07.07
# ...                                                  ...         ...
# 13886       햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트  2022.02.12
# 13887       햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트  2021.10.23
# 13888       햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트  2022.04.01
# 13889       햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트  2020.12.11
# 13890       햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트  2022.04.01
#
#                  ID  평점                                                 리뷰   꾹
# ...

# %%
b = pd.read_csv('./1점리뷰1차.csv',encoding = 'utf-8-sig', index_col=0)
b
# Out:
#                                                     상품명          날짜  \
# 0        삼성전자 갤럭시버즈 라이브 블루투스 이어폰 노이즈캔슬링 ANC 이어셋 SM-R180  2020.11.09
# 1        삼성전자 갤럭시버즈 라이브 블루투스 이어폰 노이즈캔슬링 ANC 이어셋 SM-R180  2020.09.22
# 2        삼성전자 갤럭시버즈 라이브 블루투스 이어폰 노이즈캔슬링 ANC 이어셋 SM-R180  2020.08.24
# 3        삼성전자 갤럭시버즈 라이브 블루투스 이어폰 노이즈캔슬링 ANC 이어셋 SM-R180  2020.11.26
# 4        삼성전자 갤럭시버즈 라이브 블루투스 이어폰 노이즈캔슬링 ANC 이어셋 SM-R180  2020.08.27
# ...                                                 ...         ...
# 1465  국산 에어 키높이 깔창 198종/기능성 신발 구두 운동화 메모리폼 라텍스 등산화 뒤...  2019.05.27
# 1466  국산 에어 키높이 깔창 198종/기능성 신발 구두 운동화 메모리폼 라텍스 등산화 뒤...  2021.01.13
# 1467  국산 에어 키높이 깔창 198종/기능성 신발 구두 운동화 메모리폼 라텍스 등산화 뒤...  2016.12.17
# 1468  국산 에어 키높이 깔창 198종/기능성 신발 구두 운동화 메모리폼 라텍스 등산화 뒤...  2019.11.23
# 1469  국산 에어 키높이 깔창 198종/기능성 신발 구두 운동화 메모리폼 라텍스 등산화 뒤...  2016.02.25
#
#               ID  평점                                                 리뷰   꾹
# ...

# %%
rev_star1_0825 = pd.concat([a, b], axis=0)
rev_star1_0825
# Out:
#                                                     상품명          날짜  \
# 0     [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2018.11.06
# 1     [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2018.12.09
# 2     [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2020.02.01
# 3     [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2020.10.30
# 4     [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...  2020.07.07
# ...                                                 ...         ...
# 1465  국산 에어 키높이 깔창 198종/기능성 신발 구두 운동화 메모리폼 라텍스 등산화 뒤...  2019.05.27
# 1466  국산 에어 키높이 깔창 198종/기능성 신발 구두 운동화 메모리폼 라텍스 등산화 뒤...  2021.01.13
# 1467  국산 에어 키높이 깔창 198종/기능성 신발 구두 운동화 메모리폼 라텍스 등산화 뒤...  2016.12.17
# 1468  국산 에어 키높이 깔창 198종/기능성 신발 구두 운동화 메모리폼 라텍스 등산화 뒤...  2019.11.23
# 1469  국산 에어 키높이 깔창 198종/기능성 신발 구두 운동화 메모리폼 라텍스 등산화 뒤...  2016.02.25
#
#                 ID  평점                                                 리뷰   꾹
# ...

# %%
rev_star1_0825.to_csv("rev_star1_0825.csv", encoding='utf-8-sig')
