# %%
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import random

import pandas as pd

# %% [markdown]
# # 1점대 크롤링

# %%
review_star = []
review_name = []
review_date = []
review_review = []
kkuk_lst = []

url = "https://www.11st.co.kr/products/4748079219?inpu=&trTypeCd=&trCtgrNo="
# 리뷰 5000개짜리

driver = webdriver.Chrome("chromedriver.exe")
driver.get(url)
driver.implicitly_wait(3)

# iframe 때문에 에러 뜸
# frame은 총 4개 있고 그 중 ifrmReview를 찾아내서
# ifrmReview인 곳에 switch 하기
iframe = driver.find_element(By.ID, "ifrmReview") 
driver.switch_to.frame(iframe)

# 평점 고르는 버튼 누르기
driver.find_element(By.XPATH, "/html/body/div[2]/ul/li[1]/div[1]/div[1]/button").send_keys(Keys.ENTER)
time.sleep(random.uniform(0,2))

# 평점 1점 누르기
driver.find_element(By.XPATH, "/html/body/div[2]/ul/li[1]/div[1]/div[2]/dl/dd[6]/label/span").click()
time.sleep(random.uniform(0,2))
    
    #  끝날 때까지 더 보기 누르기
p = 0
while True:
    try:
        driver.find_element(By.XPATH, "/html/body/div[2]/div[2]/div/button").send_keys(Keys.ENTER)
        # driver.implicitly_wait(3)
        p = p + 1
        # 리뷰 1000개당 15초 쉬기
        if p % 50 == 0:
            driver.execute_script("window.scrollBy(0,250);")
            time.sleep(15)
            print(p, "번째 스크롤 끝")
    # 더 누를 더보기 버튼이 없으면 몇번 눌렀는지 나오고 while문 빠져나오기
    except:
        print(f"총 {p}번 더보기 버튼 누름")
        break

# try:
star = driver.find_elements(By.CSS_SELECTOR,'p.grade > span > em')
name = driver.find_elements(By.CLASS_NAME, "name")
date = driver.find_elements(By.CLASS_NAME, "date")
review = driver.find_elements(By.CLASS_NAME, "cont_text_wrap")
kkuk = driver.find_elements(By.CLASS_NAME,'kkukCount')

# 리뷰 내용이 없을 수 있으므로
# try except 문으로 처리하기
for i in range(len(star)):
    try:
        review_review.append(review[i].text)
        review_star.append(star[i].text)
        review_name.append(name[i].text)
        review_date.append(date[i].text)
        kkuk_lst.append(kkuk[i].text)
        # 얼마나 했는지 확인
        if i % 100 == 0:
            print(i)
    except:
        review_star.append(None)
        review_name.append(None)
        review_date.append(None)
        review_review.append(None)
        kkuk_lst.append(None)
        continue


driver.quit()
data = pd.DataFrame([ x for x in zip(review_date,review_name,review_star,review_review,kkuk_lst)],columns = ['날짜','ID','평점','리뷰','꾹'])    
data
# Out:
# C:\Users\009\AppData\Local\Temp\ipykernel_9688\3576787780.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# 총 0번 더보기 버튼 누름
# Empty DataFrame
# Columns: [날짜, ID, 평점, 리뷰, 꾹]
# Index: []

# %%
data = pd.DataFrame([ x for x in zip(review_date,review_name,review_star,review_review,kkuk_lst)],columns = ['날짜','ID','평점','리뷰','꾹'])    
data
# Out:
#             날짜                              ID    평점  \
# 0   2022.05.08                            로제37     1
# 1   2022.04.17                       blue*****     1
# 2   2022.04.18                         dud2***     1
# 3   2022.03.03                          딸기씨빼먹기     1
# 4   2022.03.08  soon**************************     1
# 5   2022.03.08  soon**************************     1
# 6   2022.03.08  soon**************************     1
# 7   2022.05.05                           미소천사맘     1
# 8   2022.05.05                           미소천사맘     1
# 9   2022.04.01                          엄마처럼찌렴     1
# 10  2022.04.18                         dud2***     1
# 11  2022.03.06                             김나도     1
# 12  2022.04.20                       dmsr*****     1
# 13  2022.04.16                        micr****     1
# 14  2022.04.18                        nada****     1
# 15  2022.04.15                          ek38**     1
# 16  2022.07.25                            얼음마녀     1
# 17  2022.04.18                       dlco*****     1
# 18  2022.04.17                         uny2***     1
# 19  2022.03.01                        jine****     1
# 20  2022.05.08                    wind********     1
# 21  2022.03.13                         wook***     1
# 22  2022.05.30                          wj01**     1
# 23  2022.03.01                        jine****     1
# 24  2022.06.20                             제시야     1
# 25  2022.03.01                        jine****     1
# 26  2022.07.31                        qodm****     1
# 27  2022.05.10                        jang****     1
# 28  2022.03.10                         katy***     1
# 29        None                            None  None
# 30        None                            None  None
# 31        None                            None  None
# 32        None                            None  None
# 33        None                            None  None
# 34        None                            None  None
# 35        None                            None  None
# 36        None                            None  None
# 37        None                            None  None
# 38        None                            None  None
#
#                                                    리뷰     꾹
# 0   맛있다는 평이 많아 주문해 봤는데 진짜 사람마다 입맛이 달라도 이렇게 다를 수 있는...     0
# 1   맛정말없어요 진짜 괜히샀어요 떡은그냥 떡이고 소스는 너무맛없어서 신랑도 못먹겠다해서...     0
# 2   정말 저희 가족 입맛에는 안맞네요\n막내는 맛있다고 잘먹는데\n나머지 가족은 못먹었...     0
# 3            이게뭐에요\n장난하는거에요\n이럴꺼면보내지를말지\n이렇게배송하는게어딨어요     2
# 4           배송 느리고, 얼었던거라 그런지 떡볶이가 다 부숴지네요. 맛도 없어요 ㅜㅜ     1
# 5           배송 느리고, 얼었던거라 그런지 떡볶이가 다 부숴지네요. 맛도 없어요 ㅜㅜ     1
# 6           배송 느리고, 얼었던거라 그런지 떡볶이가 다 부숴지네요. 맛도 없어요 ㅜㅜ     1
# 7         디박 맛없음요 싼게 비지떡이네요\n맛없어서 구매한지 오래됐는데 안먹게 되네요ㅠ     0
# 8                        맛없어요 떡볶이 매일 먹는사람인데 이건 손이 안가요     0
# 9                               아 떡이\n떡이 너무 맛없어\n아..,     0
# 10                                       저는 별로예요 맛없어요     0
# 11  순한맛은 무슨...ㅠ\n아이들과 저는 매운걸 못 먹어서...처음 다른 떡볶이에 도전...     0
# 12  끓이면 떡이 다 풀어집니다. 롱밀떡은 쫄깃하게 먹는 맛인데\n냉장실에서 해동해서 찬...     0
# 13  이게 정상적인 포장 상태로 배송된건가요?\n택배 업체의 문제인지 처음 포장할때의 문...     1
# 14  신선식품인데 배송이 잘못되서 다른 아파트로 갔어요 다음날 찾으러가서 겨우 찾아왔고....     0
# 15  순한맛 시켰는데도 저랑 애한테는 매웠어요.\n떡이 끓이니까 갈라지고 흐물해져서 보기...     0
# 16  떡이 풀어져서 실망이예요 비주얼이 별로라\n사진도 못 찍겠어요 그러니 맛이 좋다해도...     0
# 17  밀키트 떡볶이 중 최악 이네요\n떡이 해동해서 끓였는데도\n다 떠지다 못해 곤죽이 ...     0
# 18                  롱밀떡 기대되요!!5개 주문하니 하나더 와서 더 좋아요!!!     0
# 19                             순한맛도 너무 매워요. 재구매 의사 없음     0
# 20     그냥 다시는 안삼. 사람마다 다르니..., 암튼 분식 몇십년만에 이건 아니다 싶음.     0
# 21            배송이 2주이상 걸리고 맛도 평범하네요.\n다음에는 구입 안 할거예요.     0
# 22                     비추입니다\n\n라면 스프만 쩝니다\n\n조미료 덩어리     0
# 23                        국물은 너무 맵고 .떡은 갈라지고 정말 맛이없네요     0
# 24                                      다시는 먹고 싶지 않아요     0
# 25                                         정말 맛이 없네요.     0
# 26  이게 정상적인 포장 상태로 배송된건가요?\n택배 업체의 문제인지 처음 포장할때의 문...     0
# 27  이게 정상적인 포장 상태로 배송된건가요?\n택배 업체의 문제인지 처음 포장할때의 문...     0
# 28  이게 정상적인 포장 상태로 배송된건가요?\n택배 업체의 문제인지 처음 포장할때의 문...     0
# 29                                               None  None
# 30                                               None  None
# 31                                               None  None
# 32                                               None  None
# 33                                               None  None
# 34                                               None  None
# 35                                               None  None
# 36                                               None  None
# 37                                               None  None
# 38                                               None  None

# %% [markdown]
# # 2점대 크롤링

# %%
review_star = []
review_name = []
review_date = []
review_review = []
kkuk_lst = []

url = "https://www.11st.co.kr/products/3988260134?inpu=&trTypeCd=22&trCtgrNo=895019"
# 리뷰 5000개짜리

driver = webdriver.Chrome("chromedriver.exe")
driver.get(url)
driver.implicitly_wait(3)

# iframe 때문에 에러 뜸
# frame은 총 4개 있고 그 중 ifrmReview를 찾아내서
# ifrmReview인 곳에 switch 하기
iframe = driver.find_element(By.ID, "ifrmReview") 
driver.switch_to.frame(iframe)

# 평점 고르는 버튼 누르기(3점)
driver.find_element(By.XPATH, "/html/body/div[2]/ul/li[1]/div[1]/div[1]/button").send_keys(Keys.ENTER)
time.sleep(random.uniform(0,2))

# 평점 3점 누르기
driver.find_element(By.XPATH, "/html/body/div[2]/ul/li[1]/div[1]/div[2]/dl/dd[5]/label/span").click()
time.sleep(random.uniform(0,2))
    
    #  끝날 때까지 더 보기 누르기
p = 0
while True:
    try:
        driver.find_element(By.XPATH, "/html/body/div[2]/div[2]/div/button").send_keys(Keys.ENTER)
        # driver.implicitly_wait(3)
        p = p + 1
        # 리뷰 1000개당 15초 쉬기
        if p % 50 == 0:
            driver.execute_script("window.scrollBy(0,250);")
            time.sleep(15)
            print(p, "번째 스크롤 끝")
    # 더 누를 더보기 버튼이 없으면 몇번 눌렀는지 나오고 while문 빠져나오기
    except:
        print(f"총 {p}번 더보기 버튼 누름")
        break

# try:
star = driver.find_elements(By.CSS_SELECTOR,'p.grade > span > em')
name = driver.find_elements(By.CLASS_NAME, "name")
date = driver.find_elements(By.CLASS_NAME, "date")
review = driver.find_elements(By.CLASS_NAME, "cont_text_wrap")
kkuk = driver.find_elements(By.CLASS_NAME,'kkukCount')

# 리뷰 내용이 없을 수 있으므로
# try except 문으로 처리하기
for i in range(len(star)):
    try:
        review_review.append(review[i].text)
        review_star.append(star[i].text)
        review_name.append(name[i].text)
        review_date.append(date[i].text)
        kkuk_lst.append(kkuk[i].text)
        # 얼마나 했는지 확인
        if i % 100 == 0:
            print(i)
    except:
        review_star.append(None)
        review_name.append(None)
        review_date.append(None)
        review_review.append(None)
        kkuk_lst.append(None)
        continue

# except:
#     continue
#     review_star.append(None)
#     review_name.append(None)
#     review_date.append(None)
#     review_review.append(None)
#     kkuk_lst.append(None)
driver.quit()
# Out:
# C:\Users\009\AppData\Local\Temp\ipykernel_19912\3968488546.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# 총 4번 더보기 버튼 누름
# 0

# %%
data = pd.DataFrame([ x for x in zip(review_date,review_name,review_star,review_review,kkuk_lst)],columns = ['날짜','ID','평점','리뷰','꾹'])    
data
# Out:
#             날짜        ID    평점  \
# 0   2022.06.07    리뷰에진심인     2
# 1   2022.04.19      주니꺼야     2
# 2   2022.02.28  cj12****     2
# 3   2022.04.16       우원전     2
# 4   2022.02.28  cj12****     2
# ..         ...       ...   ...
# 85        None      None  None
# 86        None      None  None
# 87        None      None  None
# 88        None      None  None
# 89        None      None  None
#
#                                                    리뷰     꾹
# 0   ■ 까르보나라 맛\n■ 로제 다음 까르보나라 먹어봤는데, 솔직히 저는 까르보나라는 ...     3
# 1   떡 비닐에 조리법이 나와있습니다\n받아서 바로 냉동실에 넣어뒀고..자연해동 30분 ...     4
# 2   배송 엄청 빠르고 제품도 신선하고 유통기한도 좋아요\n떡이 녹지않고 언상태로 왔어요...     2
# 3   뭐가 문제였을까요.. 우유 230미리 넣었는데..떡도 충분히 해동시켰고..어묵이랑 ...     0
# 4   짜장맛 맵지 않고 딱 짜장맛이에요\n밀떡이어서 빨리 퍼지더라고요\n맛은있는데 쌀이 ...     2
# ..                                                ...   ...
# 85                                               None  None
# 86                                               None  None
# 87                                               None  None
# 88                                               None  None
# 89                                               None  None
#
# [90 rows x 5 columns]

# %% [markdown]
# # 3점대 크롤링
# text 값이 없는 것도 문제없이 크롤 성공

# %%
review_star = []
review_name = []
review_date = []
review_review = []
kkuk_lst = []

url = "https://www.11st.co.kr/products/1929823447?inpu=&trTypeCd=22&trCtgrNo=895019"
# 리뷰 5000개짜리

driver = webdriver.Chrome("chromedriver.exe")
driver.get(url)
driver.implicitly_wait(3)

# iframe 때문에 에러 뜸
# frame은 총 4개 있고 그 중 ifrmReview를 찾아내서
# ifrmReview인 곳에 switch 하기
iframe = driver.find_element(By.ID, "ifrmReview") 
driver.switch_to.frame(iframe)

# 평점 고르는 버튼 누르기(3점)
driver.find_element(By.XPATH, "/html/body/div[2]/ul/li[1]/div[1]/div[1]/button").send_keys(Keys.ENTER)
time.sleep(random.uniform(0,2))

# 평점 3점 누르기
driver.find_element(By.XPATH, "/html/body/div[2]/ul/li[1]/div[1]/div[2]/dl/dd[4]/label/span").click()
time.sleep(random.uniform(0,2))
    
    #  끝날 때까지 더 보기 누르기
p = 0
while True:
    try:
        driver.find_element(By.XPATH, "/html/body/div[2]/div[2]/div/button").send_keys(Keys.ENTER)
        # driver.implicitly_wait(3)
        p = p + 1
        # 리뷰 1000개당 15초 쉬기
        if p % 50 == 0:
            driver.execute_script("window.scrollBy(0,250);")
            time.sleep(15)
            print(p, "번째 스크롤 끝")
    # 더 누를 더보기 버튼이 없으면 몇번 눌렀는지 나오고 while문 빠져나오기
    except:
        print(f"총 {p}번 더보기 버튼 누름")
        break

# try:
star = driver.find_elements(By.CSS_SELECTOR,'p.grade > span > em')
name = driver.find_elements(By.CLASS_NAME, "name")
date = driver.find_elements(By.CLASS_NAME, "date")
review = driver.find_elements(By.CLASS_NAME, "cont_text_wrap")
kkuk = driver.find_elements(By.CLASS_NAME,'kkukCount')

# 리뷰 내용이 없을 수 있으므로
# try except 문으로 처리하기
for i in range(len(star)):
    try:
        review_review.append(review[i].text)
        review_star.append(star[i].text)
        review_name.append(name[i].text)
        review_date.append(date[i].text)
        kkuk_lst.append(kkuk[i].text)
        # 얼마나 했는지 확인
        if i % 100 == 0:
            print(i)
    except:
        review_star.append(None)
        review_name.append(None)
        review_date.append(None)
        review_review.append(None)
        kkuk_lst.append(None)
        continue

driver.quit()
# Out:
# C:\Users\019\AppData\Local\Temp\ipykernel_6580\1880457264.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# 총 10번 더보기 버튼 누름
# 0
# 100

# %%
data = pd.DataFrame([ x for x in zip(review_date,review_name,review_star,review_review,kkuk_lst)],columns = ['날짜','ID','평점','리뷰','꾹'])    
data
# Out:
#              날짜               ID    평점  \
# 0    2022.08.09           뽀까뽀까77     3
# 1    2022.08.09        myfi*****     3
# 2    2022.07.29           소다미123     3
# 3    2021.09.08  izar***********     3
# 4    2022.08.04          dahy***     3
# ..          ...              ...   ...
# 210        None             None  None
# 211        None             None  None
# 212        None             None  None
# 213        None             None  None
# 214        None             None  None
#
#                                                     리뷰     꾹
# 0    첫단계부터 먹였었는데 두번째단계 가니 쫌 더 잘 먹는듯 하다가 요즘은 통 안먹네요....     0
# 1    생각보다 요기가케가 많이 짜요. 딱히 저염식을 고집하지도 않는데도 불구하고요. 아기...     0
# 2    길이가 길어서 조금씩 잘라서 줘봤는데 떡뻥보다 손에 마니 묻고 좋아하진않네요 먹어보...     0
# 3    가끔 밥에 김도 잘안먹을때 김자반 뿌려주면 그래도 먹어서 가끔 구매해요 배송 빠르고...     1
# 4                       타 브랜드 현미 과자에 비해 많이 고소한편은 아니네요.     0
# ..                                                 ...   ...
# 210                                               None  None
# 211                                               None  None
# 212                                               None  None
# 213                                               None  None
# 214                                               None  None
#
# [215 rows x 5 columns]

# %% [markdown]
# # 4점대 크롤링

# %%
review_star = []
review_name = []
review_date = []
review_review = []
kkuk_lst = []

url = "https://www.11st.co.kr/products/1929823447?inpu=&trTypeCd=22&trCtgrNo=895019"
# 리뷰 5000개짜리

driver = webdriver.Chrome("chromedriver.exe")
driver.get(url)
driver.implicitly_wait(3)

# iframe 때문에 에러 뜸
# frame은 총 4개 있고 그 중 ifrmReview를 찾아내서
# ifrmReview인 곳에 switch 하기
iframe = driver.find_element(By.ID, "ifrmReview") 
driver.switch_to.frame(iframe)

# 평점 고르는 버튼 누르기(3점)
driver.find_element(By.XPATH, "/html/body/div[2]/ul/li[1]/div[1]/div[1]/button").send_keys(Keys.ENTER)
time.sleep(random.uniform(0,2))

# 평점 4점 누르기
driver.find_element(By.XPATH, "/html/body/div[2]/ul/li[1]/div[1]/div[2]/dl/dd[3]/label/span").click()
time.sleep(random.uniform(0,2))
    
    #  끝날 때까지 더 보기 누르기
p = 0
while True:
    try:
        driver.find_element(By.XPATH, "/html/body/div[2]/div[2]/div/button").send_keys(Keys.ENTER)
        # driver.implicitly_wait(3)
        p = p + 1
        # 리뷰 1000개당 15초 쉬기
        if p % 50 == 0:
            driver.execute_script("window.scrollBy(0,250);")
            time.sleep(15)
            print(p, "번째 스크롤 끝")
    # 더 누를 더보기 버튼이 없으면 몇번 눌렀는지 나오고 while문 빠져나오기
    except:
        print(f"총 {p}번 더보기 버튼 누름")
        break

# try:
star = driver.find_elements(By.CSS_SELECTOR,'p.grade > span > em')
name = driver.find_elements(By.CLASS_NAME, "name")
date = driver.find_elements(By.CLASS_NAME, "date")
review = driver.find_elements(By.CLASS_NAME, "cont_text_wrap")
kkuk = driver.find_elements(By.CLASS_NAME,'kkukCount')

# 리뷰 내용이 없을 수 있으므로
# try except 문으로 처리하기
for i in range(len(star)):
    try:
        review_review.append(review[i].text)
        review_star.append(star[i].text)
        review_name.append(name[i].text)
        review_date.append(date[i].text)
        kkuk_lst.append(kkuk[i].text)
        # 얼마나 했는지 확인
        if i % 100 == 0:
            print(i)
    except:
        review_star.append(None)
        review_name.append(None)
        review_date.append(None)
        review_review.append(None)
        kkuk_lst.append(None)
        continue

driver.quit()
# Out:
# C:\Users\019\AppData\Local\Temp\ipykernel_6580\1334578101.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# 총 35번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500

# %%
data = pd.DataFrame([ x for x in zip(review_date,review_name,review_star,review_review,kkuk_lst)],columns = ['날짜','ID','평점','리뷰','꾹'])    
data
# Out:
#              날짜        ID    평점  \
# 0    2022.08.04    위대한쇼핑♡     4
# 1    2022.08.07    위대한쇼핑♡     4
# 2    2022.08.19      치키치키     4
# 3    2022.07.31  suse****     4
# 4    2022.08.04    ae03**     4
# ..          ...       ...   ...
# 699        None      None  None
# 700        None      None  None
# 701        None      None  None
# 702        None      None  None
# 703        None      None  None
#
#                                                     리뷰     꾹
# 0    딱딱하지 않고, 나름 부드러우면서 바삭하네요.\n제조는 22년 3월2일 유통기한은 ...     1
# 1    오리지널 짜지 않고 괜찮네요.\n밥량을 얼만큼하느냐 다르겠지만.\n바삭하고 기름쩐네...     1
# 2    십일절때 구매해서\n물량이 많아져서 그런가\n중간에 연휴도 껴서\n배송이 좀 걸렸어...     0
# 3    2단계는 가족들이 잘먹는 단계라 넉넉히 시켰고 5살 아이에게 맵지않는 1단계랑 짜장...     0
# 4    떡뻥이 크고 길어서 식당에서 식사할때 주면 굿 아이템 맛나서 아이도 잘 먹어요 단점...     2
# ..                                                 ...   ...
# 699                                               None  None
# 700                                               None  None
# 701                                               None  None
# 702                                               None  None
# 703                                               None  None
#
# [704 rows x 5 columns]

# %%
# 에러 뜬 값이 122개
data['날짜'].isna().value_counts()
# Out:
# False    582
# True     122
# Name: 날짜, dtype: int64

# %% [markdown]
# # 평점 5점 누르기

# %%
review_star = []
review_name = []
review_date = []
review_review = []
kkuk_lst = []

url = "https://www.11st.co.kr/products/1929823447?inpu=&trTypeCd=22&trCtgrNo=895019"
# 리뷰 5000개짜리

driver = webdriver.Chrome("chromedriver.exe")
driver.get(url)
driver.implicitly_wait(3)

# iframe 때문에 에러 뜸
# frame은 총 4개 있고 그 중 ifrmReview를 찾아내서
# ifrmReview인 곳에 switch 하기
iframe = driver.find_element(By.ID, "ifrmReview") 
driver.switch_to.frame(iframe)

# 평점 고르는 버튼 누르기(3점)
driver.find_element(By.XPATH, "/html/body/div[2]/ul/li[1]/div[1]/div[1]/button").send_keys(Keys.ENTER)
time.sleep(random.uniform(0,2))

# 평점 5점 누르기
driver.find_element(By.XPATH, "/html/body/div[2]/ul/li[1]/div[1]/div[2]/dl/dd[2]/label/span").click()
time.sleep(random.uniform(0,2))
    
    #  끝날 때까지 더 보기 누르기
p = 0
while True:
    try:
        driver.find_element(By.XPATH, "/html/body/div[2]/div[2]/div/button").send_keys(Keys.ENTER)
        # driver.implicitly_wait(3)
        p = p + 1
        # 리뷰 1000개당 15초 쉬기
        if p % 50 == 0:
            driver.execute_script("window.scrollBy(0,250);")
            time.sleep(15)
            print(p, "번째 스크롤 끝")
    # 더 누를 더보기 버튼이 없으면 몇번 눌렀는지 나오고 while문 빠져나오기
    except:
        print(f"총 {p}번 더보기 버튼 누름")
        break

# try:
star = driver.find_elements(By.CSS_SELECTOR,'p.grade > span > em')
name = driver.find_elements(By.CLASS_NAME, "name")
date = driver.find_elements(By.CLASS_NAME, "date")
review = driver.find_elements(By.CLASS_NAME, "cont_text_wrap")
kkuk = driver.find_elements(By.CLASS_NAME,'kkukCount')

# 리뷰 내용이 없을 수 있으므로
# try except 문으로 처리하기
for i in range(len(star)):
    try:
        review_review.append(review[i].text)
        review_star.append(star[i].text)
        review_name.append(name[i].text)
        review_date.append(date[i].text)
        kkuk_lst.append(kkuk[i].text)
        # 얼마나 했는지 확인
        if i % 100 == 0:
            print(i)
    except:
        review_star.append(None)
        review_name.append(None)
        review_date.append(None)
        review_review.append(None)
        kkuk_lst.append(None)
        continue

driver.quit()
# Out:
# C:\Users\019\AppData\Local\Temp\ipykernel_6580\2948421432.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# 총 45번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900

# %%
data = pd.DataFrame([ x for x in zip(review_date,review_name,review_star,review_review,kkuk_lst)],columns = ['날짜','ID','평점','리뷰','꾹'])    
data
# Out:
#              날짜         ID 평점  \
# 0    2022.08.09         쏘뽀  5
# 1    2022.08.02       초록이잉  5
# 2    2022.08.04      오동ㅇㅇㅇ  5
# 3    2022.08.08      딸딸딸딸맘  5
# 4    2022.08.17   부산,지호mom  5
# ..          ...        ... ..
# 915  2021.12.21   jo89****  5
# 916  2022.05.29  llzb*****  5
# 917  2021.11.17     ssa5**  5
# 918  2022.02.17      빈율할머니  5
# 919  2022.04.13         난남  5
#
#                                                     리뷰  꾹
# 0    일단 저도 먹어 봤는데 너무 맛있어요. 아이들도 고기 안에 치즈가 들어있어서 잘 먹...  1
# 1    위메*랑 11번가 행사때 두군데서 시켰어요ㅡ\n유통기한 넉넉하고\n배송오래걸렸고,\...  1
# 2    한창 밥 잘 안먹는 4세라 이것저것 주문해봤어요.\n주먹밥 만들어준다니까 밥 위에 ...  1
# 3    롱뻥 은 처음 인데 아이가 아주 맛있게 먹어서 구입한 보람이 있네요. .사르르쿵은 ...  1
# 4    돌즈음부터 먹어왔던 과자예요, 아기용 일반 과자들보단 단맛이 많은 편이예요. 한봉에...  1
# ..                                                 ... ..
# 915                          배송이 빨라서 좋네요 가격대비 품질이 좋습니다  0
# 916                                좋아요~ 확실히 덜 단게 느껴지네요  0
# 917                                유통기한이 길어서 두고 먹기 좋아요  0
# 918                          아기가 잘 먹어요 떨어지기전에 항상 구매해요!  0
# 919                              맛있게 잘 먹을 것 같아요 배송 빨라요  0
#
# [920 rows x 5 columns]

# %%
# 에러 뜬 값 없음
# Out:
# False    920
# Name: 날짜, dtype: int64
