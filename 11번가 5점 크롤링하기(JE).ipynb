# %%
import pandas as pd
product_df = pd.read_csv("product_link_fin_0824.csv", encoding='cp949',index_col=0)
# 링크 CSV 파일 이름 확인

# %%
product_df
# Out:
#                                                    상품명  \
# 0    [쿠폰적용가 8,250원~]PN풍년 몽꽁떼/통5중/통3중압력솥/스텐/인덕션냄비/곰솥...
# 1    [20%혜택] KF94 올국산 비움 오나미 에코브리즈 마스크 100매 새부리형 대형...
# 2                 [T멤버십 23,950원] 잘풀리는집 명작순수 30Mx30롤 2팩
# 3    매일두유 190ml 24팩(99.9/오리지널/검은콩/초콜릿/고단백)외 우유3종(초코...
# 4    롯데 꼬깔콘 67gx8개 외 ZERO시리즈,치토스,몽쉘,칙촉,가나,ABC,드림카카오...
# ..                                                 ...
# 460              [동원] 한입돈까스/치즈볼/통살치킨/프리미엄돈까스 등 튀김 다양구성
# 461            [농할가11,010원]한돈 냉장 삼겹살/목살 (500g/1kg) 모음전
# 462                               농심 올리브짜파게티 140g X 20
# 463       햄소세지 듬뿍 부대찌개600g * 3팩(+라면사리 1봉) 외 간편 국탕류 밀키트
# 464                                   CJ제일제당 스팸6호 선물세트
#
#                                                     링크   리뷰건수  평균별점   긍정비율  \
# 0    https://www.11st.co.kr/products/1198578172?inp...  10753   4.6  0.854
# 1    https://www.11st.co.kr/products/3809546339?inp...  30960   4.6  0.933
# 2    https://www.11st.co.kr/products/3866470153?inp...   5043   4.7  1.000
# 3    https://www.11st.co.kr/products/3839290460?inp...  11687   4.8  0.967
# 4    https://www.11st.co.kr/products/4018243755?inp...   4110   4.7  0.951
# ..                                                 ...    ...   ...    ...
# 460  https://www.11st.co.kr/products/3343747360?inp...   2722   4.5  0.938
# 461  https://www.11st.co.kr/products/4782435203?inp...     34   4.7  0.953
# 462  https://www.11st.co.kr/products/4239742274?inp...   1468   4.6  0.954
# 463  https://www.11st.co.kr/products/3198344891?inp...      2   5.0  0.913
# 464  https://www.11st.co.kr/products/3265528917?inp...   8046   4.7  0.945
#
#      판매율
# 0      4
# 1      5
# 2      2
# 3      5
# 4      5
# ..   ...
# 460    4
# 461    3
# 462    5
# 463    3
# 464    4
#
# [465 rows x 6 columns]

# %%
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import random

# %%
product_name = []
review_star = []
review_name = []
review_date = []
review_review = []
kkuk_lst = []


for i in range(104,150): 
    
    url = product_df["링크"][i] 
    
    driver = webdriver.Chrome("chromedriver.exe")
    driver.get(url)
    driver.implicitly_wait(3)
    
    iframe = driver.find_element(By.ID, "ifrmReview") 
    driver.switch_to.frame(iframe)
    
    # 평점 고르는 버튼 누르기
    try:
        driver.find_element(By.XPATH, "/html/body/div[2]/ul/li[1]/div[1]/div[1]/button").send_keys(Keys.ENTER)
        time.sleep(random.uniform(0,2))
    
        ### 평점 5점 누르기
        driver.find_element(By.XPATH, "/html/body/div[2]/ul/li[1]/div[1]/div[2]/dl/dd[2]/label/span").click()
        time.sleep(random.uniform(0,2))
    
        p = 0
        while True:
            try:
                driver.find_element(By.XPATH, "/html/body/div[2]/div[2]/div/button").send_keys(Keys.ENTER)
                # driver.implicitly_wait(3)
                p = p + 1
                # 리뷰 1000개당 15초 쉬기
                if p % 50 == 0:
                    driver.execute_script("window.scrollBy(0,250);")
                    time.sleep(15)
                    print(p, "번째 스크롤 끝")
            # 더 누를 더보기 버튼이 없으면 몇번 눌렀는지 나오고 while문 빠져나오기
            except:
                print(f"총 {p}번 더보기 버튼 누름")
                break
    
        star = driver.find_elements(By.CSS_SELECTOR,'p.grade > span > em')
        name = driver.find_elements(By.CLASS_NAME, "name")
        date = driver.find_elements(By.CLASS_NAME, "date")
        review = driver.find_elements(By.CLASS_NAME, "cont_text_wrap")
        kkuk = driver.find_elements(By.CLASS_NAME,'kkukCount')
    
    
    
        # 리뷰 내용이 없을 수 있으므로
        # try except 문으로 처리하기
        for l in range(len(review)):
            try:
                product_name.append(product_df["상품명"][i])
                review_review.append((review[l].text).replace('\n',''))
                review_star.append(star[l].text)
                review_name.append(name[l].text)
                review_date.append(date[l].text)
                kkuk_lst.append(kkuk[l].text)
                # 얼마나 했는지 확인
                if l % 100 == 0:
                    print(l)
            except:
                product_name.append(None)
                review_star.append(None)
                review_name.append(None)
                review_date.append(None)
                review_review.append(None)
                kkuk_lst.append(None)
                continue
    
        print(i,"번 완료")
        driver.quit()
    
    except:
        driver.quit()
        continue
# Out:
# C:\Users\009\AppData\Local\Temp\ipykernel_32920\1769343865.py:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# 총 0번 더보기 버튼 누름
# 0
# 104 번 완료
# 총 49번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 105 번 완료
# 50 번째 스크롤 끝
# 총 57번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 106 번 완료
# 총 32번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 107 번 완료
# 총 12번 더보기 버튼 누름
# 0
# 100
# 108 번 완료
# 50 번째 스크롤 끝
# 총 62번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 109 번 완료
# 총 47번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 110 번 완료
# 50 번째 스크롤 끝
# 총 61번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 111 번 완료
# 총 44번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 112 번 완료
# 총 30번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 113 번 완료
# 총 2번 더보기 버튼 누름
# 0
# 114 번 완료
# 총 42번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 115 번 완료
# 총 7번 더보기 버튼 누름
# 0
# 100
# 116 번 완료
# 총 0번 더보기 버튼 누름
# 0
# 117 번 완료
# 총 6번 더보기 버튼 누름
# 0
# 118 번 완료
# 총 29번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 119 번 완료
# 50 번째 스크롤 끝
# 총 70번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 121 번 완료
# 50 번째 스크롤 끝
# 총 52번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 122 번 완료
# 총 0번 더보기 버튼 누름
# 0
# 123 번 완료
# 50 번째 스크롤 끝
# 총 57번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 124 번 완료
# 50 번째 스크롤 끝
# 총 59번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 125 번 완료
# 총 0번 더보기 버튼 누름
# 0
# 126 번 완료
# 총 4번 더보기 버튼 누름
# 0
# 127 번 완료
# 50 번째 스크롤 끝
# 총 54번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 128 번 완료
# 50 번째 스크롤 끝
# 총 55번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 129 번 완료
# 총 0번 더보기 버튼 누름
# 0
# 130 번 완료
# 50 번째 스크롤 끝
# 총 59번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 131 번 완료
# 총 0번 더보기 버튼 누름
# 0
# 132 번 완료
# 50 번째 스크롤 끝
# 총 56번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 133 번 완료
# 총 7번 더보기 버튼 누름
# 0
# 100
# 134 번 완료
# 총 0번 더보기 버튼 누름
# 0
# 135 번 완료
# 50 번째 스크롤 끝
# 총 77번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 136 번 완료
# 50 번째 스크롤 끝
# 총 51번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 138 번 완료
# 총 2번 더보기 버튼 누름
# 0
# 139 번 완료
# 50 번째 스크롤 끝
# 총 55번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 140 번 완료
# 50 번째 스크롤 끝
# 총 51번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 141 번 완료
# 50 번째 스크롤 끝
# 총 63번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 142 번 완료
# 총 0번 더보기 버튼 누름
# 0
# 143 번 완료
# 총 18번 더보기 버튼 누름
# 0
# 100
# 200
# 144 번 완료
# 총 7번 더보기 버튼 누름
# 0
# 100
# 145 번 완료
# 총 2번 더보기 버튼 누름
# 0
# 146 번 완료
# 50 번째 스크롤 끝
# 총 51번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 147 번 완료
# 50 번째 스크롤 끝
# 총 56번 더보기 버튼 누름
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 148 번 완료

# %%
data = pd.DataFrame([ x for x in zip(product_name, review_date,review_name,review_star,review_review,kkuk_lst)],columns = ['상품명','날짜','ID','평점','리뷰','꾹'])    
print(data)

# %%
data.to_csv("rev_0824_star5_4.csv", encoding = "utf-8-sig")
